# %% [markdown]
# # Ejercicio 1: Introducción a Recuperación de Información
#
# ## Objetivo de la práctica
# - Entender el problema de **buscar información** en colecciones de texto.
# - Comprender por qué se necesita un **índice invertido** en recuperación de información.
# - Programar una primera solución manual y luego optimizarla con un índice.
# - Evaluar la mejora en tiempos de búsqueda cuando usamos estructuras adecuadas.

# %% [markdown]
# ## Parte 1: Búsqueda lineal en documentos
#
# ### Actividad
# 1. Se te proporcionará un conjunto de documentos de texto.
# 2. Escribe una función que:
#    - Lea todos los documentos.
#    - Busque una palabra ingresada por el usuario.
#    - Muestre en qué documentos aparece la palabra.

# %%
#colocar como variable el nombre del archivo.
#corpus = lista de documentos.

import os

# %%
corpus01 = open('/home/cesar/Escritorio/corpus/01_corpus_turismo.txt')
#print (corpus01.read())
palabra=input("Ingresa la palabra que estas buscando:")
corpus_01=False
c=0
documentos= []

for i in range (16):
    linea = corpus01.readline()
    palabras = linea.split()
    #print(palabras)
    for elemento in palabras:
        if elemento == palabra:
            c=c+1
            documentos.append(i)
            corpus_01=True

if corpus_01:
    for documento in documentos:
        print("La palabra", palabra, "esta en el documento:", documento)
else:
    print("La palabra: ", palabra, " no esta en ningun documento.")



#doc = open('/home/cesar/Escritorio/corpus')
# Out:
# La palabra:  g  no esta en ningun documento.

# %% [markdown]
# ## Parte 2: Construcción de un índice invertido
#
# ### Actividad
# 1. Escribe un programa que:
#    - Recorra todos los documentos.
#    - Construya un **índice invertido**, es decir, un diccionario donde:
#      - Cada palabra clave apunta a una lista de documentos donde aparece.
#
# 2. Escribe una nueva función de búsqueda que:
#    - Consulte directamente el índice para encontrar los documentos relevantes.
#    - Sea mucho más rápida que la búsqueda lineal.

# %%
corpus = open('/home/cesar/Escritorio/corpus/01_corpus_turismo.txt')

indice_invertido = {}

#leemos los documentos y creamos un indice invertido
for i in range (16):
    linea = corpus.readline()
    palabras = linea.split()
    for palabra in palabras:
        if palabra not in indice_invertido:
            indice_invertido[palabra] = set()
        indice_invertido[palabra].add(i)

palabra = input("Ingresa la palabra que estas buscando: ")

#busqueda usando el indice invertido
if palabra in indice_invertido:
    lista_doc = indice_invertido[palabra]
    for doc in lista_doc:
        print(f"La palabra '{palabra}' está en el documento: {doc}")

else:
    print(f"La palabra: {palabra} no está en ningún documento")
# Out:
# La palabra:  no está en ningún documento

# %% [markdown]
# ## Parte 3: Evaluación de tiempos de búsqueda
# ### Actividad
#
# 1. Realiza la búsqueda de varias palabras usando:
#       -  Corpus pequeño: 16 documentos (turismo en Ecuador).
#       -  Corpus grande: 500 documentos (versión ampliada).
# 2. Mide el tiempo de ejecución:
#       -  Para búsqueda lineal.
#       -  Para búsqueda usando índice invertido.
#       -  Grafica o presenta los resultados en una tabla comparativa.
#
# ### Ejemplo de palabras para buscar
# - quito
# - montañita
# - feriado
# - playas
# - aventura
# - galápagos

# %%
import time
corpus01 = open('/home/cesar/Escritorio/corpus/01_corpus_turismo.txt')
corpus02 = open('/home/cesar/Escritorio/corpus/01_corpus_turismo_500.txt')

palabras_buscar = ['quito', 'montañita', 'feriado', 'playas', 'aventura', 'galápagos']

inicio = time.time()
corpus01.seek(0)

for palabra in palabras_buscar:
    corpus01.seek(0)
    corpus_01 = False
    documentos = []

    for i in range(16):
         linea = corpus01.readline()
         palabras_linea = linea.lower().split()
         if palabra in palabras_linea:
            documentos.append(i)
            corpus_01 = True

    if corpus_01:
        for documento in documentos:
            print(f"[Lineal][Pequeño] La palabra '{palabra}' está en el documento: {documento}")
    else:
        print(f"[Lineal][Pequeño] La palabra '{palabra}' no está en ningún documento.")

fin = time.time()
tiempo_lineal_pequeno = fin - inicio
print(f"Tiempo búsqueda lineal corpus pequeño: {tiempo_lineal_pequeno:.6f} segundos")


inicio = time.time()
corpus02.seek(0)

for palabra in palabras_buscar:
    corpus02.seek(0)
    corpus_02 = False
    documentos = []
    for i in range(500):
        linea = corpus02.readline()
        palabras_linea = linea.lower().split()
        if palabra in palabras_linea:
            documentos.append(i)
            corpus_02 = True

    if corpus_02:
        for documento in documentos:
            print(f"[Lineal][Grande] La palabra '{palabra}' está en el documento: {documento}")
    else:
        print(f"[Lineal][Grande] La palabra '{palabra}' no está en ningún documento.")

fin = time.time()
tiempo_lineal_grande = fin - inicio
print(f"Tiempo búsqueda lineal corpus grande: {tiempo_lineal_grande:.6f} segundos")
# Out:
# [Lineal][Pequeño] La palabra 'quito' está en el documento: 2
# [Lineal][Pequeño] La palabra 'montañita' está en el documento: 15
# [Lineal][Pequeño] La palabra 'feriado' está en el documento: 13
# [Lineal][Pequeño] La palabra 'playas' está en el documento: 4
# [Lineal][Pequeño] La palabra 'playas' está en el documento: 9
# [Lineal][Pequeño] La palabra 'aventura' está en el documento: 3
# [Lineal][Pequeño] La palabra 'galápagos' está en el documento: 1
# Tiempo búsqueda lineal corpus pequeño: 0.003485 segundos
# [Lineal][Grande] La palabra 'quito' está en el documento: 3
# [Lineal][Grande] La palabra 'quito' está en el documento: 15
# [Lineal][Grande] La palabra 'quito' está en el documento: 16
# [Lineal][Grande] La palabra 'quito' está en el documento: 38
# [Lineal][Grande] La palabra 'quito' está en el documento: 42
# [Lineal][Grande] La palabra 'quito' está en el documento: 72
# [Lineal][Grande] La palabra 'quito' está en el documento: 74
# [Lineal][Grande] La palabra 'quito' está en el documento: 88
# [Lineal][Grande] La palabra 'quito' está en el documento: 103
# [Lineal][Grande] La palabra 'quito' está en el documento: 135
# [Lineal][Grande] La palabra 'quito' está en el documento: 200
# [Lineal][Grande] La palabra 'quito' está en el documento: 212
# [Lineal][Grande] La palabra 'quito' está en el documento: 237
# [Lineal][Grande] La palabra 'quito' está en el documento: 259
# [Lineal][Grande] La palabra 'quito' está en el documento: 290
# [Lineal][Grande] La palabra 'quito' está en el documento: 324
# [Lineal][Grande] La palabra 'quito' está en el documento: 354
# [Lineal][Grande] La palabra 'quito' está en el documento: 390
# [Lineal][Grande] La palabra 'quito' está en el documento: 468
# [Lineal][Grande] La palabra 'quito' está en el documento: 486
# [Lineal][Grande] La palabra 'montañita' está en el documento: 19
# [Lineal][Grande] La palabra 'montañita' está en el documento: 27
# [Lineal][Grande] La palabra 'montañita' está en el documento: 35
# [Lineal][Grande] La palabra 'montañita' está en el documento: 50
# [Lineal][Grande] La palabra 'montañita' está en el documento: 66
# [Lineal][Grande] La palabra 'montañita' está en el documento: 68
# [Lineal][Grande] La palabra 'montañita' está en el documento: 78
# [Lineal][Grande] La palabra 'montañita' está en el documento: 82
# [Lineal][Grande] La palabra 'montañita' está en el documento: 86
# [Lineal][Grande] La palabra 'montañita' está en el documento: 87
# [Lineal][Grande] La palabra 'montañita' está en el documento: 95
# [Lineal][Grande] La palabra 'montañita' está en el documento: 99
# [Lineal][Grande] La palabra 'montañita' está en el documento: 102
# [Lineal][Grande] La palabra 'montañita' está en el documento: 106
# [Lineal][Grande] La palabra 'montañita' está en el documento: 119
# [Lineal][Grande] La palabra 'montañita' está en el documento: 123
# [Lineal][Grande] La palabra 'montañita' está en el documento: 125
# [Lineal][Grande] La palabra 'montañita' está en el documento: 134
# [Lineal][Grande] La palabra 'montañita' está en el documento: 145
# [Lineal][Grande] La palabra 'montañita' está en el documento: 150
# [Lineal][Grande] La palabra 'montañita' está en el documento: 163
# [Lineal][Grande] La palabra 'montañita' está en el documento: 169
# [Lineal][Grande] La palabra 'montañita' está en el documento: 177
# [Lineal][Grande] La palabra 'montañita' está en el documento: 184
# [Lineal][Grande] La palabra 'montañita' está en el documento: 197
# [Lineal][Grande] La palabra 'montañita' está en el documento: 204
# [Lineal][Grande] La palabra 'montañita' está en el documento: 208
# [Lineal][Grande] La palabra 'montañita' está en el documento: 210
# [Lineal][Grande] La palabra 'montañita' está en el documento: 218
# [Lineal][Grande] La palabra 'montañita' está en el documento: 228
# [Lineal][Grande] La palabra 'montañita' está en el documento: 232
# [Lineal][Grande] La palabra 'montañita' está en el documento: 234
# [Lineal][Grande] La palabra 'montañita' está en el documento: 235
# [Lineal][Grande] La palabra 'montañita' está en el documento: 238
# [Lineal][Grande] La palabra 'montañita' está en el documento: 243
# [Lineal][Grande] La palabra 'montañita' está en el documento: 265
# [Lineal][Grande] La palabra 'montañita' está en el documento: 267
# [Lineal][Grande] La palabra 'montañita' está en el documento: 272
# [Lineal][Grande] La palabra 'montañita' está en el documento: 276
# [Lineal][Grande] La palabra 'montañita' está en el documento: 297
# [Lineal][Grande] La palabra 'montañita' está en el documento: 298
# [Lineal][Grande] La palabra 'montañita' está en el documento: 299
# [Lineal][Grande] La palabra 'montañita' está en el documento: 311
# [Lineal][Grande] La palabra 'montañita' está en el documento: 315
# [Lineal][Grande] La palabra 'montañita' está en el documento: 317
# [Lineal][Grande] La palabra 'montañita' está en el documento: 320
# [Lineal][Grande] La palabra 'montañita' está en el documento: 321
# [Lineal][Grande] La palabra 'montañita' está en el documento: 322
# [Lineal][Grande] La palabra 'montañita' está en el documento: 326
# [Lineal][Grande] La palabra 'montañita' está en el documento: 327
# [Lineal][Grande] La palabra 'montañita' está en el documento: 369
# [Lineal][Grande] La palabra 'montañita' está en el documento: 380
# [Lineal][Grande] La palabra 'montañita' está en el documento: 383
# [Lineal][Grande] La palabra 'montañita' está en el documento: 386
# [Lineal][Grande] La palabra 'montañita' está en el documento: 389
# [Lineal][Grande] La palabra 'montañita' está en el documento: 395
# [Lineal][Grande] La palabra 'montañita' está en el documento: 402
# [Lineal][Grande] La palabra 'montañita' está en el documento: 404
# [Lineal][Grande] La palabra 'montañita' está en el documento: 405
# [Lineal][Grande] La palabra 'montañita' está en el documento: 408
# [Lineal][Grande] La palabra 'montañita' está en el documento: 412
# [Lineal][Grande] La palabra 'montañita' está en el documento: 416
# [Lineal][Grande] La palabra 'montañita' está en el documento: 418
# [Lineal][Grande] La palabra 'montañita' está en el documento: 421
# [Lineal][Grande] La palabra 'montañita' está en el documento: 422
# [Lineal][Grande] La palabra 'montañita' está en el documento: 429
# [Lineal][Grande] La palabra 'montañita' está en el documento: 449
# [Lineal][Grande] La palabra 'montañita' está en el documento: 450
# [Lineal][Grande] La palabra 'montañita' está en el documento: 466
# [Lineal][Grande] La palabra 'montañita' está en el documento: 475
# [Lineal][Grande] La palabra 'montañita' está en el documento: 479
# [Lineal][Grande] La palabra 'montañita' está en el documento: 482
# [Lineal][Grande] La palabra 'montañita' está en el documento: 492
# [Lineal][Grande] La palabra 'montañita' está en el documento: 493
# [Lineal][Grande] La palabra 'feriado' no está en ningún documento.
# [Lineal][Grande] La palabra 'playas' está en el documento: 19
# [Lineal][Grande] La palabra 'playas' está en el documento: 27
# [Lineal][Grande] La palabra 'playas' está en el documento: 35
# [Lineal][Grande] La palabra 'playas' está en el documento: 50
# [Lineal][Grande] La palabra 'playas' está en el documento: 66
# [Lineal][Grande] La palabra 'playas' está en el documento: 68
# [Lineal][Grande] La palabra 'playas' está en el documento: 78
# [Lineal][Grande] La palabra 'playas' está en el documento: 82
# [Lineal][Grande] La palabra 'playas' está en el documento: 86
# [Lineal][Grande] La palabra 'playas' está en el documento: 95
# [Lineal][Grande] La palabra 'playas' está en el documento: 99
# [Lineal][Grande] La palabra 'playas' está en el documento: 102
# [Lineal][Grande] La palabra 'playas' está en el documento: 119
# [Lineal][Grande] La palabra 'playas' está en el documento: 123
# [Lineal][Grande] La palabra 'playas' está en el documento: 134
# [Lineal][Grande] La palabra 'playas' está en el documento: 150
# [Lineal][Grande] La palabra 'playas' está en el documento: 163
# [Lineal][Grande] La palabra 'playas' está en el documento: 169
# [Lineal][Grande] La palabra 'playas' está en el documento: 197
# [Lineal][Grande] La palabra 'playas' está en el documento: 218
# [Lineal][Grande] La palabra 'playas' está en el documento: 228
# [Lineal][Grande] La palabra 'playas' está en el documento: 232
# [Lineal][Grande] La palabra 'playas' está en el documento: 234
# [Lineal][Grande] La palabra 'playas' está en el documento: 235
# [Lineal][Grande] La palabra 'playas' está en el documento: 238
# [Lineal][Grande] La palabra 'playas' está en el documento: 243
# [Lineal][Grande] La palabra 'playas' está en el documento: 265
# [Lineal][Grande] La palabra 'playas' está en el documento: 272
# [Lineal][Grande] La palabra 'playas' está en el documento: 276
# [Lineal][Grande] La palabra 'playas' está en el documento: 297
# [Lineal][Grande] La palabra 'playas' está en el documento: 298
# [Lineal][Grande] La palabra 'playas' está en el documento: 320
# [Lineal][Grande] La palabra 'playas' está en el documento: 321
# [Lineal][Grande] La palabra 'playas' está en el documento: 326
# [Lineal][Grande] La palabra 'playas' está en el documento: 327
# [Lineal][Grande] La palabra 'playas' está en el documento: 369
# [Lineal][Grande] La palabra 'playas' está en el documento: 383
# [Lineal][Grande] La palabra 'playas' está en el documento: 389
# [Lineal][Grande] La palabra 'playas' está en el documento: 395
# [Lineal][Grande] La palabra 'playas' está en el documento: 404
# [Lineal][Grande] La palabra 'playas' está en el documento: 405
# [Lineal][Grande] La palabra 'playas' está en el documento: 416
# [Lineal][Grande] La palabra 'playas' está en el documento: 418
# [Lineal][Grande] La palabra 'playas' está en el documento: 422
# [Lineal][Grande] La palabra 'playas' está en el documento: 429
# [Lineal][Grande] La palabra 'playas' está en el documento: 466
# [Lineal][Grande] La palabra 'playas' está en el documento: 479
# [Lineal][Grande] La palabra 'aventura' está en el documento: 37
# [Lineal][Grande] La palabra 'aventura' está en el documento: 53
# [Lineal][Grande] La palabra 'aventura' está en el documento: 61
# [Lineal][Grande] La palabra 'aventura' está en el documento: 76
# [Lineal][Grande] La palabra 'aventura' está en el documento: 84
# [Lineal][Grande] La palabra 'aventura' está en el documento: 89
# [Lineal][Grande] La palabra 'aventura' está en el documento: 90
# [Lineal][Grande] La palabra 'aventura' está en el documento: 96
# [Lineal][Grande] La palabra 'aventura' está en el documento: 98
# [Lineal][Grande] La palabra 'aventura' está en el documento: 201
# [Lineal][Grande] La palabra 'aventura' está en el documento: 248
# [Lineal][Grande] La palabra 'aventura' está en el documento: 254
# [Lineal][Grande] La palabra 'aventura' está en el documento: 275
# [Lineal][Grande] La palabra 'aventura' está en el documento: 277
# [Lineal][Grande] La palabra 'aventura' está en el documento: 283
# [Lineal][Grande] La palabra 'aventura' está en el documento: 310
# [Lineal][Grande] La palabra 'aventura' está en el documento: 313
# [Lineal][Grande] La palabra 'aventura' está en el documento: 329
# [Lineal][Grande] La palabra 'aventura' está en el documento: 331
# [Lineal][Grande] La palabra 'aventura' está en el documento: 336
# [Lineal][Grande] La palabra 'aventura' está en el documento: 338
# [Lineal][Grande] La palabra 'aventura' está en el documento: 376
# [Lineal][Grande] La palabra 'aventura' está en el documento: 388
# [Lineal][Grande] La palabra 'aventura' está en el documento: 391
# [Lineal][Grande] La palabra 'aventura' está en el documento: 407
# [Lineal][Grande] La palabra 'aventura' está en el documento: 438
# [Lineal][Grande] La palabra 'aventura' está en el documento: 480
# [Lineal][Grande] La palabra 'aventura' está en el documento: 483
# [Lineal][Grande] La palabra 'aventura' está en el documento: 484
# [Lineal][Grande] La palabra 'aventura' está en el documento: 489
# [Lineal][Grande] La palabra 'aventura' está en el documento: 497
# [Lineal][Grande] La palabra 'aventura' está en el documento: 499
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 11
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 22
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 23
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 24
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 30
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 41
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 46
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 80
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 83
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 93
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 124
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 127
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 138
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 172
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 226
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 242
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 287
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 294
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 303
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 305
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 307
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 337
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 349
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 358
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 393
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 398
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 442
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 457
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 460
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 463
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 465
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 477
# [Lineal][Grande] La palabra 'galápagos' está en el documento: 498
# Tiempo búsqueda lineal corpus grande: 0.021003 segundos

# %%
def construir_indice_invertido(ruta_archivo, num_lineas):
    archivo = open(ruta_archivo, 'r')
    indice = {}
    for i in range(num_lineas):
        linea = archivo.readline()
        palabras = linea.lower().split()
        for palabra in palabras:
            if palabra not in indice:
                indice[palabra] = set()
            indice[palabra].add(i)
    archivo.close()
    return indice


inicio = time.time()
indice_pequeno = construir_indice_invertido('/home/cesar/Escritorio/corpus/01_corpus_turismo.txt', 16)
fin = time.time()
tiempo_indice_pequeno = fin - inicio

inicio = time.time()
for palabra in palabras_buscar:
    if palabra in indice_pequeno:
        documentos = sorted(indice_pequeno[palabra])
        for doc in documentos:
            print(f"[Índice][Pequeño] La palabra '{palabra}' está en el documento: {doc}")
    else:
        print(f"[Índice][Pequeño] La palabra '{palabra}' no está en ningún documento.")
fin = time.time()
tiempo_busqueda_indice_pequeno = fin - inicio

print(f"Tiempo búsqueda índice invertido corpus pequeño: {tiempo_busqueda_indice_pequeno:.6f} segundos")


inicio = time.time()
indice_grande = construir_indice_invertido('/home/cesar/Escritorio/corpus/01_corpus_turismo_500.txt', 500)
fin = time.time()
tiempo_indice_grande = fin - inicio

inicio = time.time()
for palabra in palabras_buscar:
    if palabra in indice_grande:
        documentos = sorted(indice_grande[palabra])
        for doc in documentos:
            print(f"[Índice][Grande] La palabra '{palabra}' está en el documento: {doc}")
    else:
        print(f"[Índice][Grande] La palabra '{palabra}' no está en ningún documento.")
fin = time.time()
tiempo_busqueda_indice_grande = fin - inicio

print(f"Tiempo búsqueda índice invertido corpus grande: {tiempo_busqueda_indice_grande:.6f} segundos")
# Out:
# [Índice][Pequeño] La palabra 'quito' está en el documento: 2
# [Índice][Pequeño] La palabra 'montañita' está en el documento: 15
# [Índice][Pequeño] La palabra 'feriado' está en el documento: 13
# [Índice][Pequeño] La palabra 'playas' está en el documento: 4
# [Índice][Pequeño] La palabra 'playas' está en el documento: 9
# [Índice][Pequeño] La palabra 'aventura' está en el documento: 3
# [Índice][Pequeño] La palabra 'galápagos' está en el documento: 1
# Tiempo búsqueda índice invertido corpus pequeño: 0.000396 segundos
# [Índice][Grande] La palabra 'quito' está en el documento: 3
# [Índice][Grande] La palabra 'quito' está en el documento: 15
# [Índice][Grande] La palabra 'quito' está en el documento: 16
# [Índice][Grande] La palabra 'quito' está en el documento: 38
# [Índice][Grande] La palabra 'quito' está en el documento: 42
# [Índice][Grande] La palabra 'quito' está en el documento: 72
# [Índice][Grande] La palabra 'quito' está en el documento: 74
# [Índice][Grande] La palabra 'quito' está en el documento: 88
# [Índice][Grande] La palabra 'quito' está en el documento: 103
# [Índice][Grande] La palabra 'quito' está en el documento: 135
# [Índice][Grande] La palabra 'quito' está en el documento: 200
# [Índice][Grande] La palabra 'quito' está en el documento: 212
# [Índice][Grande] La palabra 'quito' está en el documento: 237
# [Índice][Grande] La palabra 'quito' está en el documento: 259
# [Índice][Grande] La palabra 'quito' está en el documento: 290
# [Índice][Grande] La palabra 'quito' está en el documento: 324
# [Índice][Grande] La palabra 'quito' está en el documento: 354
# [Índice][Grande] La palabra 'quito' está en el documento: 390
# [Índice][Grande] La palabra 'quito' está en el documento: 468
# [Índice][Grande] La palabra 'quito' está en el documento: 486
# [Índice][Grande] La palabra 'montañita' está en el documento: 19
# [Índice][Grande] La palabra 'montañita' está en el documento: 27
# [Índice][Grande] La palabra 'montañita' está en el documento: 35
# [Índice][Grande] La palabra 'montañita' está en el documento: 50
# [Índice][Grande] La palabra 'montañita' está en el documento: 66
# [Índice][Grande] La palabra 'montañita' está en el documento: 68
# [Índice][Grande] La palabra 'montañita' está en el documento: 78
# [Índice][Grande] La palabra 'montañita' está en el documento: 82
# [Índice][Grande] La palabra 'montañita' está en el documento: 86
# [Índice][Grande] La palabra 'montañita' está en el documento: 87
# [Índice][Grande] La palabra 'montañita' está en el documento: 95
# [Índice][Grande] La palabra 'montañita' está en el documento: 99
# [Índice][Grande] La palabra 'montañita' está en el documento: 102
# [Índice][Grande] La palabra 'montañita' está en el documento: 106
# [Índice][Grande] La palabra 'montañita' está en el documento: 119
# [Índice][Grande] La palabra 'montañita' está en el documento: 123
# [Índice][Grande] La palabra 'montañita' está en el documento: 125
# [Índice][Grande] La palabra 'montañita' está en el documento: 134
# [Índice][Grande] La palabra 'montañita' está en el documento: 145
# [Índice][Grande] La palabra 'montañita' está en el documento: 150
# [Índice][Grande] La palabra 'montañita' está en el documento: 163
# [Índice][Grande] La palabra 'montañita' está en el documento: 169
# [Índice][Grande] La palabra 'montañita' está en el documento: 177
# [Índice][Grande] La palabra 'montañita' está en el documento: 184
# [Índice][Grande] La palabra 'montañita' está en el documento: 197
# [Índice][Grande] La palabra 'montañita' está en el documento: 204
# [Índice][Grande] La palabra 'montañita' está en el documento: 208
# [Índice][Grande] La palabra 'montañita' está en el documento: 210
# [Índice][Grande] La palabra 'montañita' está en el documento: 218
# [Índice][Grande] La palabra 'montañita' está en el documento: 228
# [Índice][Grande] La palabra 'montañita' está en el documento: 232
# [Índice][Grande] La palabra 'montañita' está en el documento: 234
# [Índice][Grande] La palabra 'montañita' está en el documento: 235
# [Índice][Grande] La palabra 'montañita' está en el documento: 238
# [Índice][Grande] La palabra 'montañita' está en el documento: 243
# [Índice][Grande] La palabra 'montañita' está en el documento: 265
# [Índice][Grande] La palabra 'montañita' está en el documento: 267
# [Índice][Grande] La palabra 'montañita' está en el documento: 272
# [Índice][Grande] La palabra 'montañita' está en el documento: 276
# [Índice][Grande] La palabra 'montañita' está en el documento: 297
# [Índice][Grande] La palabra 'montañita' está en el documento: 298
# [Índice][Grande] La palabra 'montañita' está en el documento: 299
# [Índice][Grande] La palabra 'montañita' está en el documento: 311
# [Índice][Grande] La palabra 'montañita' está en el documento: 315
# [Índice][Grande] La palabra 'montañita' está en el documento: 317
# [Índice][Grande] La palabra 'montañita' está en el documento: 320
# [Índice][Grande] La palabra 'montañita' está en el documento: 321
# [Índice][Grande] La palabra 'montañita' está en el documento: 322
# [Índice][Grande] La palabra 'montañita' está en el documento: 326
# [Índice][Grande] La palabra 'montañita' está en el documento: 327
# [Índice][Grande] La palabra 'montañita' está en el documento: 369
# [Índice][Grande] La palabra 'montañita' está en el documento: 380
# [Índice][Grande] La palabra 'montañita' está en el documento: 383
# [Índice][Grande] La palabra 'montañita' está en el documento: 386
# [Índice][Grande] La palabra 'montañita' está en el documento: 389
# [Índice][Grande] La palabra 'montañita' está en el documento: 395
# [Índice][Grande] La palabra 'montañita' está en el documento: 402
# [Índice][Grande] La palabra 'montañita' está en el documento: 404
# [Índice][Grande] La palabra 'montañita' está en el documento: 405
# [Índice][Grande] La palabra 'montañita' está en el documento: 408
# [Índice][Grande] La palabra 'montañita' está en el documento: 412
# [Índice][Grande] La palabra 'montañita' está en el documento: 416
# [Índice][Grande] La palabra 'montañita' está en el documento: 418
# [Índice][Grande] La palabra 'montañita' está en el documento: 421
# [Índice][Grande] La palabra 'montañita' está en el documento: 422
# [Índice][Grande] La palabra 'montañita' está en el documento: 429
# [Índice][Grande] La palabra 'montañita' está en el documento: 449
# [Índice][Grande] La palabra 'montañita' está en el documento: 450
# [Índice][Grande] La palabra 'montañita' está en el documento: 466
# [Índice][Grande] La palabra 'montañita' está en el documento: 475
# [Índice][Grande] La palabra 'montañita' está en el documento: 479
# [Índice][Grande] La palabra 'montañita' está en el documento: 482
# [Índice][Grande] La palabra 'montañita' está en el documento: 492
# [Índice][Grande] La palabra 'montañita' está en el documento: 493
# [Índice][Grande] La palabra 'feriado' no está en ningún documento.
# [Índice][Grande] La palabra 'playas' está en el documento: 19
# [Índice][Grande] La palabra 'playas' está en el documento: 27
# [Índice][Grande] La palabra 'playas' está en el documento: 35
# [Índice][Grande] La palabra 'playas' está en el documento: 50
# [Índice][Grande] La palabra 'playas' está en el documento: 66
# [Índice][Grande] La palabra 'playas' está en el documento: 68
# [Índice][Grande] La palabra 'playas' está en el documento: 78
# [Índice][Grande] La palabra 'playas' está en el documento: 82
# [Índice][Grande] La palabra 'playas' está en el documento: 86
# [Índice][Grande] La palabra 'playas' está en el documento: 95
# [Índice][Grande] La palabra 'playas' está en el documento: 99
# [Índice][Grande] La palabra 'playas' está en el documento: 102
# [Índice][Grande] La palabra 'playas' está en el documento: 119
# [Índice][Grande] La palabra 'playas' está en el documento: 123
# [Índice][Grande] La palabra 'playas' está en el documento: 134
# [Índice][Grande] La palabra 'playas' está en el documento: 150
# [Índice][Grande] La palabra 'playas' está en el documento: 163
# [Índice][Grande] La palabra 'playas' está en el documento: 169
# [Índice][Grande] La palabra 'playas' está en el documento: 197
# [Índice][Grande] La palabra 'playas' está en el documento: 218
# [Índice][Grande] La palabra 'playas' está en el documento: 228
# [Índice][Grande] La palabra 'playas' está en el documento: 232
# [Índice][Grande] La palabra 'playas' está en el documento: 234
# [Índice][Grande] La palabra 'playas' está en el documento: 235
# [Índice][Grande] La palabra 'playas' está en el documento: 238
# [Índice][Grande] La palabra 'playas' está en el documento: 243
# [Índice][Grande] La palabra 'playas' está en el documento: 265
# [Índice][Grande] La palabra 'playas' está en el documento: 272
# [Índice][Grande] La palabra 'playas' está en el documento: 276
# [Índice][Grande] La palabra 'playas' está en el documento: 297
# [Índice][Grande] La palabra 'playas' está en el documento: 298
# [Índice][Grande] La palabra 'playas' está en el documento: 320
# [Índice][Grande] La palabra 'playas' está en el documento: 321
# [Índice][Grande] La palabra 'playas' está en el documento: 326
# [Índice][Grande] La palabra 'playas' está en el documento: 327
# [Índice][Grande] La palabra 'playas' está en el documento: 369
# [Índice][Grande] La palabra 'playas' está en el documento: 383
# [Índice][Grande] La palabra 'playas' está en el documento: 389
# [Índice][Grande] La palabra 'playas' está en el documento: 395
# [Índice][Grande] La palabra 'playas' está en el documento: 404
# [Índice][Grande] La palabra 'playas' está en el documento: 405
# [Índice][Grande] La palabra 'playas' está en el documento: 416
# [Índice][Grande] La palabra 'playas' está en el documento: 418
# [Índice][Grande] La palabra 'playas' está en el documento: 422
# [Índice][Grande] La palabra 'playas' está en el documento: 429
# [Índice][Grande] La palabra 'playas' está en el documento: 466
# [Índice][Grande] La palabra 'playas' está en el documento: 479
# [Índice][Grande] La palabra 'aventura' está en el documento: 37
# [Índice][Grande] La palabra 'aventura' está en el documento: 53
# [Índice][Grande] La palabra 'aventura' está en el documento: 61
# [Índice][Grande] La palabra 'aventura' está en el documento: 76
# [Índice][Grande] La palabra 'aventura' está en el documento: 84
# [Índice][Grande] La palabra 'aventura' está en el documento: 89
# [Índice][Grande] La palabra 'aventura' está en el documento: 90
# [Índice][Grande] La palabra 'aventura' está en el documento: 96
# [Índice][Grande] La palabra 'aventura' está en el documento: 98
# [Índice][Grande] La palabra 'aventura' está en el documento: 201
# [Índice][Grande] La palabra 'aventura' está en el documento: 248
# [Índice][Grande] La palabra 'aventura' está en el documento: 254
# [Índice][Grande] La palabra 'aventura' está en el documento: 275
# [Índice][Grande] La palabra 'aventura' está en el documento: 277
# [Índice][Grande] La palabra 'aventura' está en el documento: 283
# [Índice][Grande] La palabra 'aventura' está en el documento: 310
# [Índice][Grande] La palabra 'aventura' está en el documento: 313
# [Índice][Grande] La palabra 'aventura' está en el documento: 329
# [Índice][Grande] La palabra 'aventura' está en el documento: 331
# [Índice][Grande] La palabra 'aventura' está en el documento: 336
# [Índice][Grande] La palabra 'aventura' está en el documento: 338
# [Índice][Grande] La palabra 'aventura' está en el documento: 376
# [Índice][Grande] La palabra 'aventura' está en el documento: 388
# [Índice][Grande] La palabra 'aventura' está en el documento: 391
# [Índice][Grande] La palabra 'aventura' está en el documento: 407
# [Índice][Grande] La palabra 'aventura' está en el documento: 438
# [Índice][Grande] La palabra 'aventura' está en el documento: 480
# [Índice][Grande] La palabra 'aventura' está en el documento: 483
# [Índice][Grande] La palabra 'aventura' está en el documento: 484
# [Índice][Grande] La palabra 'aventura' está en el documento: 489
# [Índice][Grande] La palabra 'aventura' está en el documento: 497
# [Índice][Grande] La palabra 'aventura' está en el documento: 499
# [Índice][Grande] La palabra 'galápagos' está en el documento: 11
# [Índice][Grande] La palabra 'galápagos' está en el documento: 22
# [Índice][Grande] La palabra 'galápagos' está en el documento: 23
# [Índice][Grande] La palabra 'galápagos' está en el documento: 24
# [Índice][Grande] La palabra 'galápagos' está en el documento: 30
# [Índice][Grande] La palabra 'galápagos' está en el documento: 41
# [Índice][Grande] La palabra 'galápagos' está en el documento: 46
# [Índice][Grande] La palabra 'galápagos' está en el documento: 80
# [Índice][Grande] La palabra 'galápagos' está en el documento: 83
# [Índice][Grande] La palabra 'galápagos' está en el documento: 93
# [Índice][Grande] La palabra 'galápagos' está en el documento: 124
# [Índice][Grande] La palabra 'galápagos' está en el documento: 127
# [Índice][Grande] La palabra 'galápagos' está en el documento: 138
# [Índice][Grande] La palabra 'galápagos' está en el documento: 172
# [Índice][Grande] La palabra 'galápagos' está en el documento: 226
# [Índice][Grande] La palabra 'galápagos' está en el documento: 242
# [Índice][Grande] La palabra 'galápagos' está en el documento: 287
# [Índice][Grande] La palabra 'galápagos' está en el documento: 294
# [Índice][Grande] La palabra 'galápagos' está en el documento: 303
# [Índice][Grande] La palabra 'galápagos' está en el documento: 305
# [Índice][Grande] La palabra 'galápagos' está en el documento: 307
# [Índice][Grande] La palabra 'galápagos' está en el documento: 337
# [Índice][Grande] La palabra 'galápagos' está en el documento: 349
# [Índice][Grande] La palabra 'galápagos' está en el documento: 358
# [Índice][Grande] La palabra 'galápagos' está en el documento: 393
# [Índice][Grande] La palabra 'galápagos' está en el documento: 398
# [Índice][Grande] La palabra 'galápagos' está en el documento: 442
# [Índice][Grande] La palabra 'galápagos' está en el documento: 457
# [Índice][Grande] La palabra 'galápagos' está en el documento: 460
# [Índice][Grande] La palabra 'galápagos' está en el documento: 463
# [Índice][Grande] La palabra 'galápagos' está en el documento: 465
# [Índice][Grande] La palabra 'galápagos' está en el documento: 477
# [Índice][Grande] La palabra 'galápagos' está en el documento: 498
# Tiempo búsqueda índice invertido corpus grande: 0.003358 segundos

# %% [markdown]
# | Método                         | Corpus 16 documentos | Corpus 500 documentos |
# |---------------------------------|-----------------------|------------------------|
# | Búsqueda lineal                 | 0,0025 s              | 0,022 s                |
# | Búsqueda con índice invertido   | 0,00058 s             | 0,0042 s               |
#
# La búsqueda usando índice invertido es aproximadamente **4,31 veces más rápida** en el corpus de 16 documentos,
# y aproximadamente **5,24 veces más rápida** en el corpus de 500 documentos.

# %% [markdown]
# ## Parte 4:
# ### Actividad
# 1. Modifica el índice para que ignore mayúsculas/minúsculas (por ejemplo, "Playa" y "playa" deben considerarse iguales).
# 2. Permite consultas de múltiples términos (ejemplo: buscar documentos que contengan "playa" y "turismo").
# 3. Calcula el _speedup_

# %%
import time

def construir_indice_invertido(ruta_archivo, num_lineas):
    archivo = open(ruta_archivo, 'r')
    indice = {}
    for i in range(num_lineas):
        linea = archivo.readline()
        palabras = linea.lower().split()
        for palabra in palabras:
            if palabra not in indice:
                indice[palabra] = set()
            indice[palabra].add(i)
    archivo.close()
    return indice

def busqueda_lineal(ruta_archivo, num_lineas, terminos):
    archivo = open(ruta_archivo, 'r')
    documentos_encontrados = set()
    for i in range(num_lineas):
        linea = archivo.readline()
        palabras_linea = linea.lower().split()
        if all(termino in palabras_linea for termino in terminos):
            documentos_encontrados.add(i)
    archivo.close()
    return documentos_encontrados

def busqueda_indice(indice, terminos):
    listas_documentos = []
    for termino in terminos:
        if termino in indice:
            listas_documentos.append(indice[termino])
        else:
            return set()
    return set.intersection(*listas_documentos)

ruta_pequeno = '/home/cesar/Escritorio/corpus/01_corpus_turismo.txt'
n_docs_pequeno = 16
terminos_busqueda = input("Ingresa los términos separados por espacio: ").lower().split()

inicio = time.time()
resultado_lineal = busqueda_lineal(ruta_pequeno, n_docs_pequeno, terminos_busqueda)
fin = time.time()
tiempo_lineal = fin - inicio

print("\n[Lineal][Pequeño] Documentos encontrados:", sorted(resultado_lineal))
print(f"Tiempo búsqueda lineal: {tiempo_lineal:.6f} segundos")

inicio = time.time()
indice_pequeno = construir_indice_invertido(ruta_pequeno, n_docs_pequeno)
resultado_indice = busqueda_indice(indice_pequeno, terminos_busqueda)
fin = time.time()
tiempo_indice = fin - inicio

print("\n[Índice][Pequeño] Documentos encontrados:", sorted(resultado_indice))
print(f"Tiempo búsqueda con índice: {tiempo_indice:.6f} segundos")

speedup = tiempo_lineal / tiempo_indice if tiempo_indice > 0 else float('inf')
print(f"\nSpeedup: {speedup:.2f}x más rápido usando índice invertido.")
# Out:
# [Lineal][Pequeño] Documentos encontrados: [2]
# Tiempo búsqueda lineal: 0.000375 segundos
#
# [Índice][Pequeño] Documentos encontrados: [2]
# Tiempo búsqueda con índice: 0.001276 segundos
#
# Speedup: 0.29x más rápido usando índice invertido.
